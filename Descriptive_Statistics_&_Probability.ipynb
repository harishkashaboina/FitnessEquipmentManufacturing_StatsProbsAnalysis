# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data.csv')

df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
df.shape #which shows that data contains 180 rows 9 columns
# Out:
# (180, 9)

# %%
df.info() # which gives basic information about each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
# Product          180 non-null object
# Age              180 non-null int64
# Gender           180 non-null object
# Education        180 non-null int64
# MaritalStatus    180 non-null object
# Usage            180 non-null int64
# Fitness          180 non-null int64
# Income           180 non-null int64
# Miles            180 non-null int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# #### Obeservation :
# - There is no missing values / null values

# %%
df.describe(include='all')
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      KP281         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %% [markdown]
# #### Obeservations:
#
# - Number of unique products 3
# - Most selling product is KP281 (Top value) and out of 180, 80 KP281 products sold
# - Minimum age is 18 and Maximum age is 50
# - Most of the products bought by Males (Top value) and its frequency is 104
# - Minimum education is 12 years and maximum is 21 years.
# - Most of the product brought by Partnered (MaritalStatus). ie, 107 products out of 180
# - The average number of times the customer plans to use the treadmill each week is 3.455556 and average fitness is 3.311111.
# - From the given data, Minimum income of the customer 29562, Maximum is 104581 and average income is 53719.

# %%
df['Product'].value_counts()
# Out:
# KP281    80
# KP481    60
# KP781    40
# Name: Product, dtype: int64

# %% [markdown]
# #### Observation:
#
# - Most selling product is KP281 (80 times) and least one is KP781 (40 times).

# %% [markdown]
# ## Checking Outliers - Using box plot

# %%
sns.boxplot(data=df,x="Age", showmeans=True)

plt.show()

# %% [markdown]
# - Outliers are there in Age

# %%
sns.boxplot(data=df,x="Income", showmeans=True)

plt.show()

# %% [markdown]
# - Outliers are there in Income

# %%
sns.boxplot(data=df,x="Education", showmeans=True)

plt.show()

# %%
df['Education'].median()
# Out:
# 16.0

# %% [markdown]
# - Outliers are there in Education column
# - There is no upper quartile

# %% [markdown]
# ## Data Visualization

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df, x="MaritalStatus",
palette="viridis", width=0.2)
plt.xticks(fontsize=10)
plt.title("Analysis of sells of the product by Marital Status")
plt.show()

# %% [markdown]
# #### Observation:
# - Most of the products brought by Partnered (Marital Status)

# %%
sns.histplot(df["Age"], bins=10)
plt.title("Analysis of sells of the product by Age")
plt.show()

# %% [markdown]
# #### Observation :
# - Most of the products brought by customer who's ages between around 23 to 30

# %%
sns.histplot(df["Income"], bins=10)
plt.title("Analysis of sells of the product by Age")
plt.show()

# %% [markdown]
# #### Observation :
# - Most of the product brought by customers whos income is between around 40000 to 60000

# %% [markdown]
# ## Marginal Probability

# %%
pd.crosstab(df.Product, df.Gender, margins=True)
# Out:
# Gender   Female  Male  All
# Product
# KP281        40    40   80
# KP481        29    31   60
# KP781         7    33   40
# All          76   104  180

# %%
pd.crosstab(df.Product, df.Gender, margins=True, normalize='all')
# Out:
# Gender     Female      Male       All
# Product
# KP281    0.222222  0.222222  0.444444
# KP481    0.161111  0.172222  0.333333
# KP781    0.038889  0.183333  0.222222
# All      0.422222  0.577778  1.000000

# %% [markdown]
# #### Observation
#
# - Probability of KP281 purchase is P(Purchase of KP281) = 80/180 = 0.444444
#
# - Probability of KP281 purchase is P(Purchase of KP481) = 60/180 = 0.333333
#
# - Probability of KP281 purchase is P(Purchase of KP781) = 40/180 = 0.222222
#
# - Probability of Male purchaing a product (Any product) P(Male purchasing product)= 104/180 = 0.577778
#
# - Probability of Female purchaing a product (Any product) P(Female purchasing product)= 76/180 = 0.422222

# %%
pd.crosstab(df.Product, df.MaritalStatus, margins=True)
# Out:
# MaritalStatus  Partnered  Single  All
# Product
# KP281                 48      32   80
# KP481                 36      24   60
# KP781                 23      17   40
# All                  107      73  180

# %%
pd.crosstab(df.Product, df.MaritalStatus, margins=True, normalize='all')
# Out:
# MaritalStatus  Partnered    Single       All
# Product
# KP281           0.266667  0.177778  0.444444
# KP481           0.200000  0.133333  0.333333
# KP781           0.127778  0.094444  0.222222
# All             0.594444  0.405556  1.000000

# %% [markdown]
# #### Observation
#
# - Probability of Partnered purchaing a product (Any product) = 107/180 = 0.594444
# - Probability of Single purchaing a product (Any product) = 73/180 = 0.405556

# %% [markdown]
# ## Joint Probability

# %%
pd.crosstab(df.Product, df.Gender, margins=True)
# Out:
# Gender   Female  Male  All
# Product
# KP281        40    40   80
# KP481        29    31   60
# KP781         7    33   40
# All          76   104  180

# %%
pd.crosstab(df.Product, df.Gender, margins=True, normalize='all')
# Out:
# Gender     Female      Male       All
# Product
# KP281    0.222222  0.222222  0.444444
# KP481    0.161111  0.172222  0.333333
# KP781    0.038889  0.183333  0.222222
# All      0.422222  0.577778  1.000000

# %% [markdown]
# #### Observation from above tables
#
# - Probability of a male customer buying a KP281 treadmill = 40/180 = 0.222222
#
# - Probability of a Female customer buying a KP281 treadmill = 40/180 = 0.222222
#
# - Probability of a male customer buying a KP481 treadmill = 31/180 = 0.172222
#
# - Probability of a Female customer buying a KP281 treadmill = 29/180 = 0.161111
#
# - Probability of a male customer buying a KP781 treadmill = 33/180 = 0.183333
#
# - Probability of a Female customer buying a KP781 treadmill = 7/180 = 0.038889

# %%
pd.crosstab(df.Product, df.MaritalStatus, margins=True)
# Out:
# MaritalStatus  Partnered  Single  All
# Product
# KP281                 48      32   80
# KP481                 36      24   60
# KP781                 23      17   40
# All                  107      73  180

# %%
pd.crosstab(df.Product, df.MaritalStatus, margins=True, normalize='all')
# Out:
# MaritalStatus  Partnered    Single       All
# Product
# KP281           0.266667  0.177778  0.444444
# KP481           0.200000  0.133333  0.333333
# KP781           0.127778  0.094444  0.222222
# All             0.594444  0.405556  1.000000

# %% [markdown]
# ## Observation
#
# - Probability of a Partnered customer buying a KP281 treadmill = 48/180 = 0.266667
#
# - Probability of a Single customer buying a KP281 treadmill = 32/180 = 0.177778
#
# - Probability of a Partnered customer buying a KP481 treadmill = 36/180 = 0.200000
#
# - Probability of a Single customer buying a KP281 treadmill = 24/180 = 0.133333
#
# - Probability of a Partnered customer buying a KP781 treadmill = 23/180 = 0.127778
#
# - Probability of a Single customer buying a KP781 treadmill = 17/180 = 0.094444

# %% [markdown]
# ## Conditional Probability

# %%
pd.crosstab(df.Product, df.Gender, margins=True)
# Out:
# Gender   Female  Male  All
# Product
# KP281        40    40   80
# KP481        29    31   60
# KP781         7    33   40
# All          76   104  180

# %%
pd.crosstab(df.Product, df.Gender, margins=True, normalize='index')
# Out:
# Gender     Female      Male
# Product
# KP281    0.500000  0.500000
# KP481    0.483333  0.516667
# KP781    0.175000  0.825000
# All      0.422222  0.577778

# %% [markdown]
# #### Observation
#
# - The probability that the purchase will be a KP281 given that the customer is female = 40/80 = 0.5
# - The probability that the purchase will be a KP281 given that the customer is male = 40/80 = 0.5
# - The probability that the purchase will be a KP481 given that the customer is female = 29/60 = 0.483333
# - The probability that the purchase will be a KP481 given that the customer is male = 31/60 = 0.516667
# - The probability that the purchase will be a KP781 given that the customer is female = 7/40 = 0.175000
# - The probability that the purchase will be a KP781 given that the customer is male = 33/40 = 0.825000

# %%
pd.crosstab(df.Product, df.MaritalStatus, margins=True)
# Out:
# MaritalStatus  Partnered  Single  All
# Product
# KP281                 48      32   80
# KP481                 36      24   60
# KP781                 23      17   40
# All                  107      73  180

# %%
pd.crosstab(df.Product, df.MaritalStatus, margins=True, normalize='index')
# Out:
# MaritalStatus  Partnered    Single
# Product
# KP281           0.600000  0.400000
# KP481           0.600000  0.400000
# KP781           0.575000  0.425000
# All             0.594444  0.405556

# %% [markdown]
# #### Observation
#
# - The probability that the purchase will be a KP281 given that the customer is Partnered = 48/80 = 0.6
# - The probability that the purchase will be a KP281 given that the customer is Single = 32/80 = 0.4
# - The probability that the purchase will be a KP481 given that the customer is Partnered = 36/60 = 0.6
# - The probability that the purchase will be a KP481 given that the customer is Single = 24/60 = 0.4
# - The probability that the purchase will be a KP781 given that the customer is Partnered = 23/40 = 0.575000
# - The probability that the purchase will be a KP781 given that the customer is Single = 17/40 = 0.425000

# %% [markdown]
# ## Customer Profiling

# %%
df_product_KP281 = df[df.Product == 'KP281']
df_product_KP281
# Out:
#    Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0    KP281   18    Male         14        Single      3        4   29562
# 1    KP281   19    Male         15        Single      2        3   31836
# 2    KP281   19  Female         14     Partnered      4        3   30699
# 3    KP281   19    Male         12        Single      3        3   32973
# 4    KP281   20    Male         13     Partnered      4        2   35247
# ..     ...  ...     ...        ...           ...    ...      ...     ...
# 75   KP281   43    Male         16     Partnered      3        3   53439
# 76   KP281   44  Female         16        Single      3        4   57987
# 77   KP281   46  Female         16     Partnered      3        2   60261
# 78   KP281   47    Male         16     Partnered      4        3   56850
# 79   KP281   50  Female         16     Partnered      3        3   64809
#
#     Miles
# 0     112
# 1      75
# 2      66
# 3      85
# 4      47
# ..    ...
# ...

# %%
df_product_KP281.describe(include='all')
# Out:
#        Product        Age Gender  Education MaritalStatus      Usage  \
# count       80  80.000000     80  80.000000            80  80.000000
# unique       1        NaN      2        NaN             2        NaN
# top      KP281        NaN   Male        NaN     Partnered        NaN
# freq        80        NaN     40        NaN            48        NaN
# mean       NaN  28.550000    NaN  15.037500           NaN   3.087500
# std        NaN   7.221452    NaN   1.216383           NaN   0.782624
# min        NaN  18.000000    NaN  12.000000           NaN   2.000000
# 25%        NaN  23.000000    NaN  14.000000           NaN   3.000000
# 50%        NaN  26.000000    NaN  16.000000           NaN   3.000000
# 75%        NaN  33.000000    NaN  16.000000           NaN   4.000000
# max        NaN  50.000000    NaN  18.000000           NaN   5.000000
#
#          Fitness       Income       Miles
# count   80.00000     80.00000   80.000000
# unique       NaN          NaN         NaN
# ...

# %%
df_product_KP481 = df[df.Product == 'KP481']
df_product_KP481.head()
# Out:
#    Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 80   KP481   19    Male         14        Single      3        3   31836
# 81   KP481   20    Male         14        Single      2        3   32973
# 82   KP481   20  Female         14     Partnered      3        3   34110
# 83   KP481   20    Male         14        Single      3        3   38658
# 84   KP481   21  Female         14     Partnered      5        4   34110
#
#     Miles
# 80     64
# 81     53
# 82    106
# 83     95
# 84    212

# %%
df_product_KP481.describe(include='all')
# Out:
#        Product        Age Gender  Education MaritalStatus      Usage  \
# count       60  60.000000     60  60.000000            60  60.000000
# unique       1        NaN      2        NaN             2        NaN
# top      KP481        NaN   Male        NaN     Partnered        NaN
# freq        60        NaN     31        NaN            36        NaN
# mean       NaN  28.900000    NaN  15.116667           NaN   3.066667
# std        NaN   6.645248    NaN   1.222552           NaN   0.799717
# min        NaN  19.000000    NaN  12.000000           NaN   2.000000
# 25%        NaN  24.000000    NaN  14.000000           NaN   3.000000
# 50%        NaN  26.000000    NaN  16.000000           NaN   3.000000
# 75%        NaN  33.250000    NaN  16.000000           NaN   3.250000
# max        NaN  48.000000    NaN  18.000000           NaN   5.000000
#
#          Fitness        Income       Miles
# count   60.00000     60.000000   60.000000
# unique       NaN           NaN         NaN
# ...

# %%
df_product_KP781 = df[df.Product == 'KP781']
df_product_KP781.head()
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 140   KP781   22    Male         14        Single      4        3   48658
# 141   KP781   22    Male         16        Single      3        5   54781
# 142   KP781   22    Male         18        Single      4        5   48556
# 143   KP781   23    Male         16        Single      4        5   58516
# 144   KP781   23  Female         18        Single      5        4   53536
#
#      Miles
# 140    106
# 141    120
# 142    200
# 143    140
# 144    100

# %%
df_product_KP781.describe(include='all')
# Out:
#        Product        Age Gender  Education MaritalStatus      Usage  \
# count       40  40.000000     40  40.000000            40  40.000000
# unique       1        NaN      2        NaN             2        NaN
# top      KP781        NaN   Male        NaN     Partnered        NaN
# freq        40        NaN     33        NaN            23        NaN
# mean       NaN  29.100000    NaN  17.325000           NaN   4.775000
# std        NaN   6.971738    NaN   1.639066           NaN   0.946993
# min        NaN  22.000000    NaN  14.000000           NaN   3.000000
# 25%        NaN  24.750000    NaN  16.000000           NaN   4.000000
# 50%        NaN  27.000000    NaN  18.000000           NaN   5.000000
# 75%        NaN  30.250000    NaN  18.000000           NaN   5.000000
# max        NaN  48.000000    NaN  21.000000           NaN   7.000000
#
#           Fitness        Income       Miles
# count   40.000000      40.00000   40.000000
# unique        NaN           NaN         NaN
# ...

# %% [markdown]
# ## Observations based on above information
#
# #### Category 1 (Who's brought KP281 product):
#
# - Customers median age is 26 (Outliers exists so considering median instead of mean)
# - Customers average education is 15 years
# - The average number of times the customers plans to use the treadmill each week is 3.08
# - Customers average self rated fitness is 2.96
# - Customers whos average income is 46418 (near to this amount), are mostly brought KP281 product
# - The average number of miles the customer expects to walk/run each week is 82.78
#
# #### Category 2 (Who's brought KP481 product):
#
# - Customers Median age is 26
# - Customers average education is 15 years
# - The average number of times the customers plans to use the treadmill each week is 3.06
# - Customers average self rated fitness is 2.9
# - Customers whos median income is 49459 (near to this amount), are mostly brought KP481 product
# - The average number of miles the customer expects to walk/run each week is 87.9
#
# #### Category 3 (Who's brought KP781 product):
#
# - Customers Median age is 27.0 (Outliers exists so considering median instead of mean)
# - Customers average education is 17 years
# - The average number of times the customers plans to use the treadmill each week is 4.77
# - Customers average self rated fitness is 4.65
# - Customers whos average income is 75441 (near to this amount), are mostly brought KP781 product
# - The average number of miles the customer expects to walk/run each week is 166.9

# %% [markdown]
# ## Deatails Analysis of Each Product (KP281, KP481, KP781)

# %%
df_product_KP281 = df[df.Product == 'KP281']
df_product_KP281
# Out:
#    Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0    KP281   18    Male         14        Single      3        4   29562
# 1    KP281   19    Male         15        Single      2        3   31836
# 2    KP281   19  Female         14     Partnered      4        3   30699
# 3    KP281   19    Male         12        Single      3        3   32973
# 4    KP281   20    Male         13     Partnered      4        2   35247
# ..     ...  ...     ...        ...           ...    ...      ...     ...
# 75   KP281   43    Male         16     Partnered      3        3   53439
# 76   KP281   44  Female         16        Single      3        4   57987
# 77   KP281   46  Female         16     Partnered      3        2   60261
# 78   KP281   47    Male         16     Partnered      4        3   56850
# 79   KP281   50  Female         16     Partnered      3        3   64809
#
#     Miles
# 0     112
# 1      75
# 2      66
# 3      85
# 4      47
# ..    ...
# ...

# %%
df_product_KP481 = df[df.Product == 'KP481']
df_product_KP481
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 80    KP481   19    Male         14        Single      3        3   31836
# 81    KP481   20    Male         14        Single      2        3   32973
# 82    KP481   20  Female         14     Partnered      3        3   34110
# 83    KP481   20    Male         14        Single      3        3   38658
# 84    KP481   21  Female         14     Partnered      5        4   34110
# 85    KP481   21    Male         16     Partnered      2        2   34110
# 86    KP481   21    Male         12     Partnered      2        2   32973
# 87    KP481   23    Male         14     Partnered      3        3   36384
# 88    KP481   23    Male         14     Partnered      3        3   38658
# 89    KP481   23  Female         16        Single      3        3   45480
# 90    KP481   23    Male         16     Partnered      4        3   45480
# 91    KP481   23  Female         16     Partnered      3        2   43206
# ...

# %%
df_product_KP781 = df[df.Product == 'KP781']
df_product_KP781
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 140   KP781   22    Male         14        Single      4        3   48658
# 141   KP781   22    Male         16        Single      3        5   54781
# 142   KP781   22    Male         18        Single      4        5   48556
# 143   KP781   23    Male         16        Single      4        5   58516
# 144   KP781   23  Female         18        Single      5        4   53536
# 145   KP781   23    Male         16        Single      4        5   48556
# 146   KP781   24    Male         16        Single      4        5   61006
# 147   KP781   24    Male         18     Partnered      4        5   57271
# 148   KP781   24  Female         16        Single      5        5   52291
# 149   KP781   24    Male         16        Single      5        5   49801
# 150   KP781   25    Male         16     Partnered      4        5   49801
# 151   KP781   25    Male         16     Partnered      4        4   62251
# ...

# %% [markdown]
# #### Analysis of KP281 product customer details

# %%
df_product_KP281.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
df_product_KP281.shape
# Out:
# (80, 9)

# %% [markdown]
# - There are total 80 rows for KP281 Product

# %%
df_product_KP281.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80 entries, 0 to 79
# Data columns (total 9 columns):
# Product          80 non-null object
# Age              80 non-null int64
# Gender           80 non-null object
# Education        80 non-null int64
# MaritalStatus    80 non-null object
# Usage            80 non-null int64
# Fitness          80 non-null int64
# Income           80 non-null int64
# Miles            80 non-null int64
# dtypes: int64(6), object(3)
# memory usage: 6.2+ KB

# %%
df_product_KP281.describe(include='all')
# Out:
#        Product        Age Gender  Education MaritalStatus      Usage  \
# count       80  80.000000     80  80.000000            80  80.000000
# unique       1        NaN      2        NaN             2        NaN
# top      KP281        NaN   Male        NaN     Partnered        NaN
# freq        80        NaN     40        NaN            48        NaN
# mean       NaN  28.550000    NaN  15.037500           NaN   3.087500
# std        NaN   7.221452    NaN   1.216383           NaN   0.782624
# min        NaN  18.000000    NaN  12.000000           NaN   2.000000
# 25%        NaN  23.000000    NaN  14.000000           NaN   3.000000
# 50%        NaN  26.000000    NaN  16.000000           NaN   3.000000
# 75%        NaN  33.000000    NaN  16.000000           NaN   4.000000
# max        NaN  50.000000    NaN  18.000000           NaN   5.000000
#
#          Fitness       Income       Miles
# count   80.00000     80.00000   80.000000
# unique       NaN          NaN         NaN
# ...

# %%
sns.boxplot(data=df_product_KP281,
            x="Age", showmeans=True)

plt.show()

# %%
df_product_KP281['Age'].median()
# Out:
# 26.0

# %% [markdown]
# - There are some outliers there in age
# - Median age of the customer who bought KP281 Product is 26

# %%
sns.boxplot(data=df_product_KP281,
            x="Income", showmeans=True)

plt.show()

# %%
df_product_KP281['Income'].median()
# Out:
# 46617.0

# %%
sns.boxplot(data=df_product_KP281,
            x="Usage", showmeans=True)

plt.show()

# %%
df_product_KP281['Usage'].median()
# Out:
# 3.0

# %% [markdown]
# - There are no outliers
# - No lower quartile
# - Median is 3

# %%
sns.boxplot(data=df_product_KP281,
            x="Education", showmeans=True)

plt.show()

# %%
df_product_KP281['Education'].median()
# Out:
# 16.0

# %% [markdown]
# - There are no outliers
# - Median is 16
# - No upper quartile

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df_product_KP281, x="MaritalStatus",
palette="viridis", width=0.2)
plt.xticks(rotation=45,fontsize=10)
plt.title("Count of Movie / TV Show Per release on each day of week")
plt.show()

# %% [markdown]
# #### Analysis of KP481 product customer details

# %%
df_product_KP481.shape
# Out:
# (60, 9)

# %%
df_product_KP481.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 80 to 139
# Data columns (total 9 columns):
# Product          60 non-null object
# Age              60 non-null int64
# Gender           60 non-null object
# Education        60 non-null int64
# MaritalStatus    60 non-null object
# Usage            60 non-null int64
# Fitness          60 non-null int64
# Income           60 non-null int64
# Miles            60 non-null int64
# dtypes: int64(6), object(3)
# memory usage: 4.7+ KB

# %%
df_product_KP481.describe(include='all')
# Out:
#        Product        Age Gender  Education MaritalStatus      Usage  \
# count       60  60.000000     60  60.000000            60  60.000000
# unique       1        NaN      2        NaN             2        NaN
# top      KP481        NaN   Male        NaN     Partnered        NaN
# freq        60        NaN     31        NaN            36        NaN
# mean       NaN  28.900000    NaN  15.116667           NaN   3.066667
# std        NaN   6.645248    NaN   1.222552           NaN   0.799717
# min        NaN  19.000000    NaN  12.000000           NaN   2.000000
# 25%        NaN  24.000000    NaN  14.000000           NaN   3.000000
# 50%        NaN  26.000000    NaN  16.000000           NaN   3.000000
# 75%        NaN  33.250000    NaN  16.000000           NaN   3.250000
# max        NaN  48.000000    NaN  18.000000           NaN   5.000000
#
#          Fitness        Income       Miles
# count   60.00000     60.000000   60.000000
# unique       NaN           NaN         NaN
# ...

# %%
sns.boxplot(data=df_product_KP481,
            x="Age", showmeans=True) # checking outlier

plt.show()

# %%
df_product_KP481['Age'].median()
# Out:
# 26.0

# %% [markdown]
# - There are some outlier.
# - Median age is 26

# %%
sns.boxplot(data=df_product_KP481,
            x="Income", showmeans=True) # checking outlier

plt.show()

# %%
df_product_KP481['Income'].median()
# Out:
# 49459.5

# %% [markdown]
# - There are some outliers
# - Median income is 49459.5

# %%
sns.boxplot(data=df_product_KP481,
            x="Education", showmeans=True) # checking outlier

plt.show()

# %%
df_product_KP481['Education'].median()
# Out:
# 16.0

# %% [markdown]
# - There is no upper quartile
# - No outliers
# - Median is 16

# %% [markdown]
# #### Analysis of KP781 product customer details

# %%
df_product_KP781.head()
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 140   KP781   22    Male         14        Single      4        3   48658
# 141   KP781   22    Male         16        Single      3        5   54781
# 142   KP781   22    Male         18        Single      4        5   48556
# 143   KP781   23    Male         16        Single      4        5   58516
# 144   KP781   23  Female         18        Single      5        4   53536
#
#      Miles
# 140    106
# 141    120
# 142    200
# 143    140
# 144    100

# %%
df_product_KP781.shape
# Out:
# (40, 9)

# %%
df_product_KP781.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 140 to 179
# Data columns (total 9 columns):
# Product          40 non-null object
# Age              40 non-null int64
# Gender           40 non-null object
# Education        40 non-null int64
# MaritalStatus    40 non-null object
# Usage            40 non-null int64
# Fitness          40 non-null int64
# Income           40 non-null int64
# Miles            40 non-null int64
# dtypes: int64(6), object(3)
# memory usage: 3.1+ KB

# %%
df_product_KP781.describe(include='all')
# Out:
#        Product        Age Gender  Education MaritalStatus      Usage  \
# count       40  40.000000     40  40.000000            40  40.000000
# unique       1        NaN      2        NaN             2        NaN
# top      KP781        NaN   Male        NaN     Partnered        NaN
# freq        40        NaN     33        NaN            23        NaN
# mean       NaN  29.100000    NaN  17.325000           NaN   4.775000
# std        NaN   6.971738    NaN   1.639066           NaN   0.946993
# min        NaN  22.000000    NaN  14.000000           NaN   3.000000
# 25%        NaN  24.750000    NaN  16.000000           NaN   4.000000
# 50%        NaN  27.000000    NaN  18.000000           NaN   5.000000
# 75%        NaN  30.250000    NaN  18.000000           NaN   5.000000
# max        NaN  48.000000    NaN  21.000000           NaN   7.000000
#
#           Fitness        Income       Miles
# count   40.000000      40.00000   40.000000
# unique        NaN           NaN         NaN
# ...

# %%
sns.boxplot(data=df_product_KP781,
            x="Age", showmeans=True) # checking outlier

plt.show()

# %%
df_product_KP781['Age'].median()
# Out:
# 27.0

# %% [markdown]
# - There are some outliers
# - Median age is 27

# %%
sns.boxplot(data=df_product_KP781,
            x="Income", showmeans=True) # checking outlier

plt.show()

# %%
sns.boxplot(data=df_product_KP781,
            x="Education", showmeans=True) # checking outlier

plt.show()

# %%
df_product_KP781['Education'].median()
# Out:
# 18.0

# %% [markdown]
# - There is no upper quartile
# - There is no outliers
# - Median is 18

# %% [markdown]
# ## Recommendations and Actionable Insights

# %%
pd.crosstab(df.Product, [df.Gender,df.MaritalStatus], values=df.Age, aggfunc=[np.average,np.min,np.max])
# Out:
#                  average                                       amin         \
# Gender            Female                  Male               Female
# MaritalStatus  Partnered     Single  Partnered     Single Partnered Single
# Product
# KP281          28.333333  28.692308  31.380952  25.631579        19     22
# KP481          30.000000  28.142857  30.380952  25.200000        20     23
# KP781          29.000000  24.333333  30.000000  28.928571        25     23
#
#                                     amax
# Gender             Male           Female             Male
# MaritalStatus Partnered Single Partnered Single Partnered Single
# Product
# KP281                20     18        50     44        47     38
# KP481                21     19        40     40        48     34
# KP781                24     22        33     26        48     45

# %%
pd.crosstab(df.Product, [df.Gender,df.MaritalStatus], values=df.Income, aggfunc=[np.average,np.min,np.max])
# Out:
#                     average                                            \
# Gender               Female                        Male
# MaritalStatus     Partnered        Single     Partnered        Single
# Product
# KP281          46153.777778  45742.384615  50028.000000  43265.842105
# KP481          49724.800000  48920.357143  49378.285714  47071.800000
# KP781          84972.250000  58516.000000  81431.368421  68216.428571
#
#                    amin                              amax                   \
# Gender           Female             Male           Female             Male
# MaritalStatus Partnered Single Partnered Single Partnered Single Partnered
# Product
# KP281             30699  34110     35247  29562     64809  67083     68220
# KP481             34110  40932     32973  31836     64809  65220     64809
# KP781             61006  52291     49801  48556     95866  69721    104581
#
#
# Gender
# MaritalStatus Single
# Product
# KP281          54576
# KP481          67083
# ...

# %%
pd.crosstab(df.Product, [df.Gender,df.MaritalStatus], values=df.Fitness, aggfunc=[np.average,np.min,np.max])
# Out:
#                 average                                    amin         \
# Gender           Female                Male              Female
# MaritalStatus Partnered    Single Partnered    Single Partnered Single
# Product
# KP281          2.851852  2.923077  2.857143  3.263158         2      2
# KP481          2.933333  2.785714  2.904762  3.000000         2      1
# KP781          5.000000  4.000000  4.631579  4.642857         5      3
#
#                                     amax
# Gender             Male           Female             Male
# MaritalStatus Partnered Single Partnered Single Partnered Single
# Product
# KP281                 1      3         5      4         4      5
# KP481                 2      2         4      4         4      4
# KP781                 3      3         5      5         5      5

# %%
pd.crosstab(df.Product, [df.Gender,df.MaritalStatus], values=df.Education, aggfunc=[np.average,np.min,np.max])
# Out:
#                  average                                       amin         \
# Gender            Female                  Male               Female
# MaritalStatus  Partnered     Single  Partnered     Single Partnered Single
# Product
# KP281          14.888889  15.538462  15.428571  14.473684        14     14
# KP481          15.200000  15.214286  15.285714  14.500000        14     13
# KP781          17.500000  18.333333  17.421053  16.928571        16     16
#
#                                     amax
# Gender             Male           Female             Male
# MaritalStatus Partnered Single Partnered Single Partnered Single
# Product
# KP281                13     12        16     18        18     16
# KP481                12     14        16     18        16     16
# KP781                14     14        18     21        21     21

# %% [markdown]
# #### Recommendations and Actionable Insights

# %% [markdown]
# - Suppose if we have a customer income information, based on his income we can recommend correct product.
#     1. If customer average income is 46418 (Near to this amount), best affordable product is KP281 (Also considering customers usage and miles per week)
#     2. If customer average income is 48973 (Near to this amount), best affordable product is KP481 (Also considering customers usage and miles per week)
#     3. If customer average income is 75441 (Near to this amount), best affordable product is KP781 (Also considering customers usage and miles per week)
#
# - The average income of Catogery 1 and Categery 2 is very nearer to each other. So If a customer plans to buys product KP281, Aerofit company convience the customer to buy product KP481 by explaining the features of it and also giving a small amount of discount on product KP481. So that company may benefit.
#
# - If a customer looking for more fitness product, Based on data we can recommend Product KP781
#
# - If a customer completed his/her >= 17 years eductions, More tend to buy KP781 product, so that we can recommend KP781 product.
#
# - Based on data, Most selling product is KP281, So aerofit company may manufacture/(maintain inventory) this product accordingly, so that they may reach the market/customer demand without losing customer
#
# - Average age of customer, Average income of the customer, Average usage of the customer, Average miles per week of the customer and Average income of the customer is almost same as Product KP281 and Product KP481. But Most selling product is KP281 compare to KP481, we can analyze the gap try to explain the KP481 features to customers clearly and may offer some small amount of discounts on KP481, so that customers can buy the product, aerofit company may benefit from it.
